# %%
import pandas as pd

# %%
df = pd.read_pickle("ref_merged.pickle")

# %%
df
# Out:
#      ORF_Q    ORF_A        STR_ID_Q  GENE_Q         STR_ID_A      GENE_A  \
# 0  YBL097W  YAL002W  YBL097W_tsq510  brn1-9    YAL002W_dma23        vps8
# 1  YBL097W  YAL010C  YBL097W_tsq510  brn1-9    YAL010C_dma18       mdm10
# 2  YBL097W  YAL024C  YBL097W_tsq510  brn1-9  YAL024C_dma5246  lte1-supp1
# 3  YBL097W  YPL110C  YBL097W_tsq510  brn1-9  YPL110C_dma4858        gde1
# 4  YBL097W  YPL115C  YBL097W_tsq510  brn1-9  YPL115C_dma4853        bem3
#
#     TEMP     GIS         GIS_P   SMF_Q  \
# 0  DMA30 -0.0689  8.744000e-02  0.5464
# 1  DMA30 -0.0149  3.764000e-01  0.5464
# 2  DMA30  0.1376  2.209000e-09  0.5464
# 3  DMA30  0.0336  0.000000e+00  0.5464
# 4  DMA30 -0.0271  2.169000e-01  0.5464
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                               AUTH_A  \
# ...
